# %% [markdown]
# PubPol 542: Group Project

# %% [markdown]
# Cleaning Data

# %% [markdown]
# Graduation & Dropout Data

# %%
#collecting data from github repository

import pandas as pd

location='https://raw.githubusercontent.com/madelynsather/PUBPOL542/main/Report_Card_Graduation_2018-19.csv?token=ASLS26AUAJN6LPFKUARNA2TABYUSS'
grad=pd.read_csv(location)

# %%
grad.head()
# Out:
#    SchoolYear OrganizationLevel    County      ESDName  ESDOrganizationID  \
# 0        2019             State  Multiple  State Total                NaN
# 1        2019             State  Multiple  State Total                NaN
# 2        2019             State  Multiple  State Total                NaN
# 3        2019             State  Multiple  State Total                NaN
# 4        2019             State  Multiple  State Total                NaN
#
#    DistrictCode DistrictName  DistrictOrganizationId  SchoolCode   SchoolName  \
# 0           NaN  State Total                     NaN         NaN  State Total
# 1           NaN  State Total                     NaN         NaN  State Total
# 2           NaN  State Total                     NaN         NaN  State Total
# 3           NaN  State Total                     NaN         NaN  State Total
# 4           NaN  State Total                     NaN         NaN  State Total
#
# ...

# %%
grad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81265 entries, 0 to 81264
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SchoolYear              81265 non-null  int64
#  1   OrganizationLevel       81265 non-null  object
#  2   County                  81265 non-null  object
#  3   ESDName                 75773 non-null  object
#  4   ESDOrganizationID       79301 non-null  float64
#  5   DistrictCode            76616 non-null  float64
#  6   DistrictName            77637 non-null  object
#  7   DistrictOrganizationId  80244 non-null  float64
#  8   SchoolCode              55737 non-null  float64
#  9   SchoolName              77637 non-null  object
#  10  SchoolOrganizationid    59365 non-null  float64
#  11  CurrentSchoolType       0 non-null      float64
#  12  StudentGroupType        81265 non-null  object
#  13  StudentGroup            81265 non-null  object
# ...

# %%
#see all rows and columns
pd.set_option('display.max_rows',grad.shape[0]+1)
pd.set_option('display.max_columns', None)

# %%
#drop variables we don't need
grad.drop(grad.iloc[:,[0,1,3,4,7,10,11,22,23,24]], axis=1, inplace=True)

# %%
grad.describe()
# Out:
#        DistrictCode    SchoolCode  BegginingGrade9    TransferIn  \
# count  76616.000000  55737.000000     30824.000000  28561.000000
# mean   22469.144226   3494.391679       441.520893     73.790378
# std    10445.823795   1293.318617      2913.909588    465.578670
# min     1109.000000   1500.000000         1.000000      1.000000
# 25%    17001.000000   2386.000000        21.000000      5.000000
# 50%    22009.000000   3330.000000        73.000000     14.000000
# 75%    31311.000000   4585.000000       234.000000     38.000000
# max    39209.000000   5957.000000     82611.000000  13057.000000
#
#        Year1Dropout  Year2Dropout  Year3Dropout  Year4Dropout   TransferOut  \
# count  10942.000000  16752.000000  21824.000000  25524.000000  31713.000000
# mean       6.282124      8.743314     14.925220     28.764300     56.499070
# std       24.267000     41.223389     83.285881    178.107012    376.797015
# ...

# %%
grad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81265 entries, 0 to 81264
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   County            81265 non-null  object
#  1   DistrictCode      76616 non-null  float64
#  2   DistrictName      77637 non-null  object
#  3   SchoolCode        55737 non-null  float64
#  4   SchoolName        77637 non-null  object
#  5   StudentGroupType  81265 non-null  object
#  6   StudentGroup      81265 non-null  object
#  7   Suppression       81265 non-null  object
#  8   Cohort            81265 non-null  object
#  9   BegginingGrade9   30824 non-null  float64
#  10  TransferIn        28561 non-null  float64
#  11  Year1Dropout      10942 non-null  float64
#  12  Year2Dropout      16752 non-null  float64
#  13  Year3Dropout      21824 non-null  float64
#  14  Year4Dropout      25524 non-null  float64
#  15  TransferOut       31713 non-null  float64
# ...

# %%
grad.describe()
# Out:
#        DistrictCode    SchoolCode  BegginingGrade9    TransferIn  \
# count  76616.000000  55737.000000     30824.000000  28561.000000
# mean   22469.144226   3494.391679       441.520893     73.790378
# std    10445.823795   1293.318617      2913.909588    465.578670
# min     1109.000000   1500.000000         1.000000      1.000000
# 25%    17001.000000   2386.000000        21.000000      5.000000
# 50%    22009.000000   3330.000000        73.000000     14.000000
# 75%    31311.000000   4585.000000       234.000000     38.000000
# max    39209.000000   5957.000000     82611.000000  13057.000000
#
#        Year1Dropout  Year2Dropout  Year3Dropout  Year4Dropout  Year5Dropout  \
# count  10942.000000  16752.000000  21824.000000  25524.000000  16099.000000
# mean       6.282124      8.743314     14.925220     28.764300     20.720480
# std       24.267000     41.223389     83.285881    178.107012    121.467262
# ...

# %%
#keep grade 12 only

grad['Cohort'].value_counts()
# Out:
# Seven Year    20411
# Six Year      20324
# Four Year     20269
# Five Year     20261
# Name: Cohort, dtype: int64

# %%
grad=grad[(grad.Cohort== 'Four Year')]

# %%
grad['Cohort'].value_counts()
# Out:
# Four Year    20269
# Name: Cohort, dtype: int64

# %%
#drop rows with state totals

grad=grad[~grad.County.str.contains("Multiple")]

# %%
grad.shape
# Out:
# (19997, 22)

# %%
grad.describe()
# Out:
#        DistrictCode    SchoolCode  BegginingGrade9   TransferIn  Year1Dropout  \
# count  19082.000000  13788.000000      7910.000000  7350.000000   2556.000000
# mean   22372.352164   3504.094140       239.612516    38.523537      3.706964
# std    10445.443763   1294.437256       838.692071   130.022457      8.394750
# min     1109.000000   1500.000000         1.000000     1.000000      1.000000
# 25%    17001.000000   2392.000000        20.000000     5.000000      1.000000
# 50%    21401.000000   3330.000000        68.000000    13.000000      2.000000
# 75%    31306.000000   4585.000000       219.000000    34.000000      3.000000
# max    39209.000000   5953.000000     20683.000000  3214.000000    135.000000
#
#        Year2Dropout  Year3Dropout  Year4Dropout  TransferOut   FinalCohort  \
# count   4226.000000   5509.000000   6497.000000  8206.000000   8206.000000
# mean       4.999290      8.408604     16.910112    29.919815    235.554594
# ...

# %%
import numpy as np

# %%
np.any(grad.isnull())
# Out:
# True

# %%
grad.to_csv('./graduation.csv', index=False)

# %%
# !ls
# Out:
# GroupProject_Graduation.ipynb      Report_Card_Graduation_2018-19.csv
# Lecture 1                          Syllabus
# Lecture 2                          graduation.csv
# Lecture 3

# %%
# !pwd
# Out:
# /Users/madelynsather/Documents/Courses/Current Courses/PubPol 542
